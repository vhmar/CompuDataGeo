# %% [markdown]
# <img style="float: right;" src="unam.png" width="120">
# <img style="float: right;" src="umdi.png" width="200">
# <h2>Universidad Nacional Autónoma de México</h2>
# **Unidad Multidisciplinaria de Docencia e Investigación
# Facultad de Ciencias**
# Lic. en Ciencias de la Tierra
# *Computación y Análisis de Datos Geofísicos*
# Axel Cerón González
# <h3><center>Libreta 1: *Regresión lineal*</center></h3>
# <hr />
#
# <h3>INTRODUCCIÓN</h3>
# <div style="text-align: justify">
# <br />
# **I. ESTADÍSTICA**
#
# La **Estadística** es una disciplina que utiliza recursos matemáticos para organizar y resumir una gran cantidad de datos obtenidos de la realizad, e inferir conclusiones respecto a ellos (Cazau, 2006).
# Si se busca el vocablo **Estadística** en el Diccionario de la Real Academia Española de la Lengua (DRAE) aparecen tres acepciones:
#    1. *Estudio de los datos cuantitativos de la población, de los recursos naturales e industriales, del tráfico o de cualquier otra manifestación de las sociedades humanas;*
#    2. *Conjunto de estos datos;*
#    3. *Rama de las matemáticas que utiliza grandes conjuntos de datos numéricos para obtener inferencias basadas en el cálculo de probabilidades.*
#
# En la actualidad, el papel de la Estadística en la Ciencia e Ingeniería es crucial, fundamentalmente porque al analizar datos recopilados en experimentos de cualquier tipo, se observa, en la mayoría de las ocasiones, que dichos datos están sujetos a algún tipo de incertidumbre. Así, el *profesional* debe tomar decisiones respecto de su objeto de análisis basándose en esos datos (Sáez-Castillo, 2012).
# <br />
# <br />
# <br />
# **II. MEDIDAS DE TENDENCIA CENTRAL**
#
# Las **medidas de tendencia central** son medidas de posición que tratan de establecer un valor que pueda considerarse el *centro* de los datos en algún sentido.
# <br />
# <br />
# **IIa. Media**
#
# Corresponde al *centro de gravedad* de los datos. Sea un conjunto de datos de una variable cuantitativa, $x_i,...,x_n$. La **media** de los datos es:
# $$\bar{x}=\frac{\sum_{i=1}^{n} x_i}{n}$$
# <br />
# <br />
# **IIb. Mediana**
#
# La **mediana** es el valor de la variable que deja el mismo número de datos antes y después que él, una vez ordenados. Sea un conjunto de datos de una variable cuantitativa, $x_i,...,x_n$. Ordenamos la muestra de menor a mayor, $x_{(1)},...,x_{(n)}$. El cálculo de la mediana dependerá de si el número de datos, $n$ es par o impar:
# <ul>
# <li>Si $n$ es impar, la mediana es el valor que ocupa la posición $\frac{n+1}{2}$ una vez que los datos han sido ordenados, porque éste es el valor central. Es decir: $$M=x_{\frac{n+1}{2}}$$</li>
# <li>Si $n$ es impar, la mediada es la media aritmética de los dos valores centrales; puesto que los dos datos que están en el centro de la muestra ocupan las posiciones $\frac{n}{2}$ y $\frac{n}{2}+1$. Es decir: $$M=\frac{x_{(n⁻²)} + x_{(n⁻² + 1)}}{2}$$</li>
# </ul>
# <br />
# <br />
# **IIc. Moda**
#
# En principio, la **moda** se define como el valor más frecuente de los datos. En aquellos datos que provienen de una variable continua o discreta con muchos valores y que los datos apenas se repiten, se deben agrupar por intervalos (**intervalo modal**).
# <br />
# <br />
# <br />
# **III. REGRESIÓN LINEAL SIMPLE**
# <br />
# <br />
# Un modelo de **regresión lineal simple** para una variable, *Y* (**variable dependiente**), dada otra variable, *X* (**variable independiente**), es un modelo matemático que permite obtener una fórmula capaz de relacionar *Y* con *X* basada sólo en relaciones lineales del tipo:
# $$Y=\beta_0 + \beta_1 X + \epsilon$$
#
# En esta expresión:
# <ul>
# <li>*Y* representa a la variable dependiente;</li>
# <li>*X* representa a la variable dependente;</li>
# <li>$\epsilon$ representa al **error aleatorio**;</li>
# <li>$\beta_0$ es la **ordenada al origen** del modelo; y</li>
# <li>$\beta_1$ es la **pendiente** de la línea.</li>
# </ul>
#
# <br />
# <br />
# <br />
# **IIIa. MÍNIMOS CUADRADOS**
# <br />
# <br />
# Si queremos obtener el modelo de regresión lineal *que mejor se ajuste a los datos de la muestra*, deberemos estimar los coeficientes $\beta_0$ y $\beta_1$. Se llama **recta de regresión por mínimos cuadrados** de *Y* dada *X* a la línea que tiene la *suma de errores cuadrados* más pequeña de entre todos los modelos lineales, y corresponde a las siguientes fórmulas:
# <br />
# $$\Delta = n\sum x^2 - ({\sum x})^2$$
# <br />
# $$b = \frac{({\sum x^2 \sum y - \sum x \sum xy})}{\Delta}$$
# <br />
# $$m = \frac{n\sum xy - \sum x \sum y}{\Delta}$$
# <br />
# $$ECM = \sqrt{\frac{\sum ({y-y'})^2}{n}}$$
# <br />
# <br />
# <br />
# **IV. Análisis de la Varianza (ANOVA)**
# <br />
# <br />
# El **Análisis de la Varianza** puede contemplarse como un caso especial de la modelización econométrica, donde el conjunto de variables explicativas son variables ficticias y la la variable dependiente es de tipo continuo. El análisis parte de los conceptos de *regresión lineal*. Permite determinar si diferentes tratamientos muestran diferencias significativas. El primer concepto fundamental es que todo valor observado puede expresarse mediante la siguiente función:
# $$y_{ij} = \mu + \tau_{i} + \epsilon_{ij}$$
#
# Donde:
# <ul>
# <li>$y_{ij}$ sería el valor observador;</li>
# <li>$\mu$ sería una constante que, en la recta de regresión, equivale a la ordenada al origen;</li>
# <li>$\tau_{i}$ es el efecto diferencial del nivel j. Recoge la importancia de cada tratamiento y es el objetivo del análisis; y</li>
# <li>$\epsilon_{ij}$ es una variable aleatoria que añade a la función cierto error que desvía la puntuación observada de la pronosticada.</li>
# </ul>
#
# El ANOVA tradiconal parte de descomponer la variación total de la muestra en dos componentes, **variación entre** y **variación intra**. Lo anterior, puede expresarse por:
# <br />
# <br />
# $$V. TOTAL = V. ENTRE + V. INTRA$$
# <br />
# $$\sum_{j=1}^{g}\sum_{i=1}^{n_{j}}({Y_{ij}-\bar{Y}})^2 = \sum_{j=1}^{g}n_{j}({\bar{Y_{j}}-\bar{Y}})^2 + \sum_{j=1}^{g}\sum_{i=1}^{n_{j}}({Y_{ij}-\bar{Y_{j}}})^2$$
# <br />
# Por tanto, el análisis de varianza se va a basar en la comparación de la variación ENTRE-grupos y la variación INTRA-grupos, teniendo en cuanta sus correspondientes grados de libertad. Así, un valor elevado de la variación intra significará que mayores son las diferencias entre los grupos; cumpliéndose, además, que la variación dentro de cada grupo sea mínima (Vicéns-Oter *et al*., 2005).
# <br />
# <br />
# Otro camino para calcular el análisis de varianza es mediante las siguientes fórmulas:
# <br />
# <br />
# $$L_{xx}=\sum{(x_{i})}^2 - \frac{(\sum x_{i})^2}{n}$$
# $$L_{yy}=\sum{(y_{i})}^2 - \frac{(\sum y_{i})^2}{n}$$
# $$L_{yx}=\sum x_{i}y_{i} - \frac{(\sum x_{i})(\sum x_{i})}{n}$$
# $$b=\frac{L_{yx}}{L_{xx}}$$
#
# <br />
# <br />
# **V. Coeficiente de Correlación de Pearson**
# <br />
# <br />
# La covarianza entre dos variables es una medida de la asociación lineal existente entre ellas. Será positiva si la relación entre ambas es directa (si crece una, crece la otra) y negativa si es inversa (si crece una, decrece la otra); además, será tanto mayor en valor absoluto cuando más fuerte sea la relación lineal existente.
# Para poder valorar esta relación lineal en términos relativos se estandariza la covarianza, dando lugar a lo que se conoce como **coeficiente de correlación lineal**:
# <br />
# <br />
# $$\rho = \frac{covarianza [x,y]}{\sqrt{(varianza [x])(varianza [y])}}$$
# <br />
# <br />
# Los posibles valores de $\rho$ y su interpretación son los siguientes:
# <ul>
# <li>Este coeficiente es siempre un número real entre -1 y 1;</li>
# <li>Si es cero, indica una ausencia total de relación lineal entre las variables;</li>
# <li>Si es uno o menos uno, indica una relación lineal total entre las variables, directa o inversa, según lo indique el signo; y</li>
# <li>En la medida en que esté más lejos del cero, indica una relación lineal más intensa entre las variables.</li>
# </ul>
#
#
#
# </div>

# %% [markdown]
# <h3>DESAROLLO</h3>

# %%
using DataFrames
using Plots
using CSV
# Out:
# INFO: Recompiling stale cache file /home/axelc/.julia/lib/v0.6/DataStreams.ji for module DataStreams.
# INFO: Recompiling stale cache file /home/axelc/.julia/lib/v0.6/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /home/axelc/.julia/lib/v0.6/CSV.ji for module CSV.

# %%
x=randn(100);
y=(5*x)+2;

# %%
pyplot()
plot(x,y, label="Curva", color="seagreen3",
    grid=1, gridcolor="grey", gridlinestyle=:dash, gridalpha=1,
    legendfont=Plots.font("Palatino",12), xlabel="x",ylabel="y",title="Curva 1",
    xlims=(-2,2.2), ylims=(-8,14),
    box=:true)

# %%
y_noise=y+randn(100)*1.2;

# %%
scatter(x,y_noise, label="Datos",
    grid=1, gridcolor="grey", gridlinestyle=:dash, gridalpha=1,
    legendfont=Plots.font("Palatino",12), xlabel="x",ylabel="y",title="Datos con ruido",
    box=:true)

# %%
linreg(x,y_noise)
b,m=linreg(x,y_noise)
y_calc=(m*x)+b;

# %%
scatter(x,y_noise, label="Datos")
plot!(x,y_calc, label="Regresión lineal", color="seagreen3",
    grid=1, gridcolor="grey", gridlinestyle=:dash, gridalpha=1,
    legendfont=Plots.font("Palatino",12), xlabel="x",ylabel="y",title="Regresión lineal",
    box=:true)

# %%
function mc(x,y)
    n=length(x)
    xs=sum(x)
    ys=sum(y)
    sx=sum(x.^2)
    sxc=(sum(x)).^2
    sxy=sum(x.*y)
    
    delta=(n*sx)-sxc
    A=((sx*ys)-(xs*sxy))/delta
    B=((n*sxy)-(xs*ys))/delta
    E=sqrt(sum((y-A-B*x).^2)/n);
    return A, B, E
end
# Out:
# mc (generic function with 1 method)

# %%
mc(x,y_noise) #Mínimos cuadrados
# Out:
# (2.0169272682369717, 5.196911164583742, 1.1730222649146744)

# %%
pyplot()
scatter(x,y_noise, label="Datos")
plot!(x,y_calc, label="Regresión lineal", color="seagreen3",
    grid=1, gridcolor="grey", gridlinestyle=:dash, gridalpha=1,
    legendfont=Plots.font("Palatino",12), xlabel="x",ylabel="y",title="Mínimos cuadrados",
    box=:true)

# %%
#No pude poner errorbar con Plots

# %%
histogram(y_noise,color="darkorange", alpha=0.7, ylims=(0,45), label="Y error",
    title="Histograma de error", box=:true,
    grid=1, gridcolor="grey", gridlinestyle=:dash, gridalpha=1, box=:true)

# %%
function ccp(x,y)
    xprom=sum(x)/length(x)
    yprom=sum(y)/length(y)
    xc=(x.-xprom)
    yc=(y.-yprom)
    
    P=(sum(xc.*yc)/sqrt(sum((xc).^2)*sum((yc).^2)))
    println(P)
end
# Out:
# ccp (generic function with 1 method)

# %%
ccp(x,y_noise) #Coeficiente de Correlación de Pearson
# Out:
# 0.9721715348936999

# %%
cor(x,y_noise) #Coeficiente de Correlación de Pearson
# Out:
# 0.9721715348936999

# %%
function anova(x,y)
    n=length(x)
    lxx=sum((x).^2)-((sum(x)).^2/n)
    lyx=sum(x.*y)-(sum(x).*sum(y)/n)
    
    b=lyx/lxx
    return b
end
# Out:
# anova (generic function with 1 method)

# %%
anova(x,y_noise) #Análisis de la Varianza
# Out:
# 5.196911164583741

# %% [markdown]
# <h3>"JULIA, PYTHON AND R: THE RISE OF JUPYTER NOTEBOOKS"</h3>
# <div style="text-align: justify">
# <br />
# Jupyter es una *multi-plataforma* en la que se pueden construir *notebooks* en los lenguajes Julia, Python y R; avance enmarcado dentro de la *big data science*. Hace sólo un par de años, las *notebooks* comenzaron a ganar adeptos, dentro de los campos empresariales, así como en la academia, tanto por su dinamismo sintáctico, como por su capacidad de ser compartidas a través de la plataforma *Github*. Aumentando las colaboraciones en conjunto, a través de las telecomunicaciones; asimismo, es un activo para la reproducción del conocimiento.
# <br />
# <br />
# 	Entre las bondades de Jupyter entre distintos lenguajes de programación, pues es posible trabajar dentro de los entornos de Julia, Python, R y muchos otros. Para Python existe gran cantidad de materiales de apoyo en Internet, puesto que ha sido bastante trabajado; por su parte, Julia, es un lenguaje nuevo, pero que comienza a responder muy bien a las exigencias del mercado, sobre todo, de manera gratuita, algo poco común hace apenas 10 años. Ésto, combinado con la capacidad de Jupyter de combinar, dentro de un mismo ambiente, códigos, comentarios, ecuaciones y animaciones.
# <br />
# <br />
# 	El auge de Julia y Jupyter comienza a generar ambientes de trabajado a nivel mundial, en cuanto a los lenguajes de programación. Haciendo eficientes las investigaciones y los procesos de enseñanza-aprendizaje. Julia se basa en el uso de *librerías/bibliotecas* (*libraries*) eficientes para cálculos de álgebra lineal,  generación de número flotantes, etcétera.
#
# </div>

# %% [markdown]
# <h3>REFERENCIAS</h3>
# **Cazau, P.** (2006) *Fundamentos de Estadística*, Universidad de Buenos Aires, 80 p.
# **Sáenz-Castillo, A.** (2012) *Apuntes de Estadística para Ingenieros*, Departamento de Estadística e Investigación Operativa, Universidad de Jaén, 235 p.
# **Vincéns-Otero, J., Herrarte-Sánchez, A. y Medina-Moral, E.** (2005) *Análisis de la varianza (ANOVA)*, Universidad Autónoma de Madrid, 14 p.
