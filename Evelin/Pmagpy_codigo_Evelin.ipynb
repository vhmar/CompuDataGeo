# %%
#Cargar paqueterías Pmagpy

import pmagpy
import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag

# %%
#Cargar otras paqueterías
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import data
Datos= pd.read_csv('Datos_Paleomag.csv')

# %%
#Renombrar columnas
Decli=Datos['Dec[deg.]']
Incli=Datos['Inc[deg.]']
Alpha=Datos['Alpha95[deg.]']
Edad=Datos['Age[yr.AD]']

# %%
#Figura
plt.figure(num=1,figsize=(4,4))
ipmag.plot_net(fignum=1)
ipmag.plot_di(Decli,Incli,color='r', label='Declinación-Inclinación', title='Direcciones del campo magnético')
plt.legend(loc=8)
plt.savefig('Polos1')
